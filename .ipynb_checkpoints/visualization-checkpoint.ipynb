# %%
#-*- coding utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
from pylab import mpl
import re
mpl.rcParams['font.sans-serif'] = ['SimHei']

#data = pd.read_csv('E:/Jupter/web_crawl/weather.csv',encoding="gb2312")
data = pd.read_csv('E:/Jupter/web_crawl/weather.csv')
#qai = data['Number']
#date = range(1,29)
#high_temp = data.iloc[1:,1:2].values
high_temp = data['High_temp']
#print high_temp
high_temp_new = []
for i in high_temp:
    #print i
    high_temp_new.append(re.findall(r'\d+',i))
#print high_temp_new
#--------------------------------------------------
low_temp = data['Low_temp']
low_temp_new = []
for j in low_temp:
    #print i
    low_temp_new.append(re.findall(r'\d+',j))
#print high_temp_new
#--------------------------------------------------
date = range(1,29)

#--------------------------------------------------
weather = data['Weather']
#print weather

#--------------------------------------------------
qua = data['Qai_lel']
#print qua

#--------------------------------------------------
plt.figure(figsize=(10, 6))
plt.ylim(12,35)
#plt.xlim(1,29)
plt.plot(date,high_temp_new,label=u'最高气温',linewidth=1,marker = 'o',linestyle = '--')
plt.plot(date,low_temp_new,label=u'最低气温',linewidth=1,marker = 'o',linestyle = '--')
plt.title(u'杭州2017年6月天气统计')
plt.legend(loc='best')
a = []
for x in range(1,29):
    a.append(x)
plt.xticks(a,rotation = -30)
plt.xlabel(u'日期')
plt.ylabel(u'温度')
#plt.grid(x1)
plt.show()

# %%
#-*- coding utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
from pylab import mpl
import re
mpl.rcParams['font.sans-serif'] = ['SimHei']

#data = pd.read_csv('E:/Jupter/web_crawl/weather.csv',encoding="gb2312")
data = pd.read_csv('E:/Jupter/web_crawl/weather.csv')

#--------------------------------------------------
date = range(1,29)

#--------------------------------------------------
qua = data['Number']
#print qua

#--------------------------------------------------
#plt.figure(figsize=(10, 6))
#plt.ylim(12,35)
#plt.xlim(1,29)
plt.scatter(date,qua,color = 'blue',marker = '*')

plt.title(u'杭州2017年6月空气质量指数')
#plt.legend(loc='best')
a = []
for x in range(1,29):
    a.append(x)
plt.xticks(a,rotation = -30)
plt.xlabel(u'日期')
plt.ylabel(u'空气质量指数')
#plt.hlines(0, 0, 0.5, colors = "c", linestyles = "dashed")
plt.axhline(100,label="1",color='orange',linewidth=1,linestyle="--")
plt.axhline(50,label="1",color='g',linewidth=1,linestyle="--")
plt.text(30,102,u'轻度污染')
plt.text(30,70,u'良')
plt.text(30,32,u'优')
#plt.grid(x1)
plt.show()

# %%
'''
c1 = data.Qai_lel[data.Qai_lel ==u'优'].value_counts()
c2 = data.Qai_lel[data.Qai_lel ==u'良'].value_counts()
c3 = data.Qai_lel[data.Qai_lel ==u'轻度污染'].value_counts()
'''
data.Qai_lel.value_counts().plot(kind='bar',color = 'blue',alpha=0.6)
plt.title(u"空气质量天数统计")
plt.ylabel(u"天数")  
#plt.ylim(0,20)
plt.yticks(range(23),rotation = 30)
plt.xticks(rotation = 360)
#plt.axhline(20,label="1",color='black',linewidth=1,linestyle="--",alpha=0.2)
#plt.axhline(7,label="1",color='black',linewidth=1,linestyle="--",alpha=0.2)
#plt.axhline(1,label="1",color='black',linewidth=1,linestyle="--",alpha=0.2)
#hlines(u'优', xmin, xmax)
plt.show()
#print c1
#print c2
#print c3

# %%
#-*- coding utf-8 -*-
#save the image
import pandas as pd
import matplotlib.pyplot as plt
from pylab import mpl
import re
mpl.rcParams['font.sans-serif'] = ['SimHei']

#data = pd.read_csv('E:/Jupter/web_crawl/weather.csv',encoding="gb2312")
data = pd.read_csv('E:/Jupter/web_crawl/weather.csv')
#qai = data['Number']
#date = range(1,29)
#high_temp = data.iloc[1:,1:2].values
high_temp = data['High_temp']
#print high_temp
high_temp_new = []
for i in high_temp:
    #print i
    high_temp_new.append(re.findall(r'\d+',i))
#print high_temp_new
#--------------------------------------------------
low_temp = data['Low_temp']
low_temp_new = []
for j in low_temp:
    #print i
    low_temp_new.append(re.findall(r'\d+',j))
#print high_temp_new
#--------------------------------------------------
date = range(1,29)
#--------------------------------------------------
weather = data['Weather']
#print weather

#--------------------------------------------------
qua = data['Qai_lel']
#print qua

#--------------------------------------------------
plt.figure(figsize=(16, 12))
plt.subplot2grid((2,2),(0,0),colspan=2)   
plt.ylim(12,35)
#plt.xlim(1,29)
plt.plot(date,high_temp_new,label=u'最高气温',linewidth=1,marker = 'o',linestyle = '--')
plt.plot(date,low_temp_new,label=u'最低气温',linewidth=1,marker = 'o',linestyle = '--')
#plt.title(u'杭州2017年6月天气统计')
plt.title(u'杭州2017年6月气温变化')
plt.legend(loc='best')
a = []
for x in range(1,29):
    a.append(x)
plt.xticks(a,rotation = -30)
plt.xlabel(u'日期')
plt.ylabel(u'温度')
#plt.grid(x1)
#plt.show()

plt.subplot2grid((2,2),(1,0))  

#--------------------------------------------------
qua = data['Number']
#print qua

#--------------------------------------------------
#plt.figure(figsize=(10, 6))
#plt.ylim(12,35)
#plt.xlim(1,29)
plt.scatter(date,qua,color = 'blue',marker = '*')

plt.title(u'杭州2017年6月空气质量指数变化')

#plt.legend(loc='best')
a = []
for x in range(1,29):
    a.append(x)
plt.xticks(a,rotation = -30)
plt.xlabel(u'日期')
plt.ylabel(u'空气质量指数')
#plt.hlines(0, 0, 0.5, colors = "c", linestyles = "dashed")
plt.axhline(100,label="1",color='orange',linewidth=1,linestyle="--")
plt.axhline(50,label="1",color='g',linewidth=1,linestyle="--")
plt.text(30,102,u'轻度污染')
plt.text(30,70,u'良')
plt.text(30,32,u'优')
#plt.grid(x1)
#plt.show()

plt.subplot2grid((2,2),(1,1)) 
data.Qai_lel.value_counts().plot(kind='bar',color = 'blue',alpha=0.6)
plt.title(u"空气质量天数统计")
plt.ylabel(u"天数")  
#plt.ylim(0,20)
plt.yticks(range(23),rotation = 30)
plt.xticks(rotation = 360)
#plt.show()

plt.savefig("E:/Jupter/web_crawl/weather.jpg")
