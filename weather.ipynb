# %%
#获取整个网页信息——非结构化数据
import requests
from bs4 import BeautifulSoup
res = requests.get('http://tianqi.eastday.com/hangzhou_history/58457_201706.html?btype=historyWeather&subtype=pre&idx=1')
res.encoding = 'utf-8'
#print res.text
soup = BeautifulSoup(res.text,'html.parser')
print soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type">
# <meta content="no-transform " http-equiv="Cache-Control">
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible">
# <!--[if lt IE 7]>
#     <html class="ie6"><![endif]--><!--[if IE 7]>
#     <html class="ie7"><![endif]--><!--[if IE 8]>
#     <html class="ie8"><![endif]--><!--[if gte IE 9]>
#     <html class="ie9"><![endif]-->
# <title>杭州6月天气_2017年6月杭州天气_杭州历史天气查询</title>
# <meta content="东方天气网为您提供2017年6月份杭州天气查询，以及往年6月份的杭州历史天气查询，包括详细的整个月份天气数据，帮您了解城市的历史天气情况。" name="description">
# <meta content="6月杭州天气，杭州天气6月，杭州历史天气" name="keywords">
# <meta content="pc" name="applicable-device">
# <link href="http://tianqi.eastday.com/data/www/tianqi_html/hangzhou_history/58457_201706.html" rel="canonical"/>
# <link href="//tianqi.eastday.com/jscss/v25/images/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="//tianqi.eastday.com/jscss/v25/v2/css/global.css" rel="stylesheet" type="text/css">
# <link href="//tianqi.eastday.com/jscss/v25/css/gxler.css" rel="stylesheet" type="text/css">
# <link href="//tianqi.eastday.com/jscss/v25/css/base.css" rel="stylesheet" type="text/css">
# <link href="//tianqi.eastday.com/jscss/v25/css/layout.css" rel="stylesheet" type="text/css">
# <link href="//tianqi.eastday.com/jscss/v25/v2/css/weatherIcon.css" rel="stylesheet" type="text/css">
# <link href="//tianqi.eastday.com/jscss/v25/v2/css/jquery.slideBox.css" rel="stylesheet" type="text/css"/>
# <script>
#         var _url_res = "//tianqi.eastday.com/jscss/v25/";
#         var _cookie_domain = "eastday.com"
#         var _url_api = "//data.dftianqi.com/";
#         var _has_local_tianqi = "0";
#         var _canonical_url = "//tianqi.eastday.com";
#         var _is_home_page = "0";
#                 var _url_tj_stat = "//tianqilog.dftoutiao.com/weather/wethact";//测试
#         var _url_tj_online = "//tianqilog.dftoutiao.com/weather/wethonline";//测试
#         // var _url_tj_stat = "http://tianqilog.dfshurufa.com/weather/wethact";//正式
#             </script>
# <script src="//tianqi.eastday.com/jscss/v25/js/jquery.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/jquery.cookie.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25//js/v2/jquery.slideBox.min.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/common.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/citySelectData2.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/globle.js"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/jquery-ui-autocomplete.js"></script>
# <script src="/data/da.js"></script>
# <script defer="defer" id="defaultCity"></script>
# <script src="//tianqi.eastday.com/jscss/v25/js/layout.js"></script>
# <script src="//dup.baidustatic.com/js/ds.js"></script>
# <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#         <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#         <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <!--[if lte ie 6]>
#         <script src="//tianqi.eastday.com/jscss/v25/js/iepng.js" typfe="text/javascript"></script>
#         <script type="text/javascript">
#            EvPNG.fix('.opacityImg,.w10_l,.w11_l,.w12_l,.w13_l,.w14_l,.w16_l,.w19_l,.w20_l,.w26_l,.w28_l,.w32_l,.w37_l,.w39_l,.w40_l,.w41_l,.w42_l,.w60_l,.w61_l,.w62_l,.w63_l,.w64_l,.w65_l,.w10, .w11, .w12, .w13, .w14, .w16, .w19, .w20, .w26, .w28, .w32, .w37, .w39, .w40, .w41, .w42, .w60, .w61, .w62, .w63, .w64, .w65,.column-name-bg,.share,.vjs-play-control,.vjs-mute-control,.vjs-fullscreen-control');
#         </script>
#     <![endif]-->
# <style>
#         body { font-family: "helvetica neue", "tahoma", "hiragino sans gb","stheiti","wenquanyi micro hei","微软雅黑","宋体","sans-serif"}
#     </style>
# </link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body id="header">
# <div class="dhx_tooltip"></div>
# <div class="dhx_tooltip"></div>
# <div class="stretch-wrap">
# <div class="stretch-bg"></div>
# </div>
# <!--[if IE 6]>
# <div id="contentWrap" class="contentWrap"><![endif]-->
# <div class="container" id="mainContainer">
# <div class="head_declareArea">
# <div class="head_declare clearfix">
# <div class="float-l">
#                 东方天气网提供全球城市天气预报查询、空气质量查询，实时更新全球城市天气预报。
#             </div>
# <div class="rightArea float-r">
# <a class="mr10" href="//mtianqi.eastday.com" target="_blank">
# <div class="mibile opacityImg">
# </div>
# <div>
#                         手机天气
#                     </div>
# </a>
# <a href="javascript:void" onclick="addfavorite()">
# <div class="collect opacityImg">
# </div>
# <div>
#                         收藏
#                     </div>
# </a>
# </div>
# </div>
# </div>
# <div class="head_w">
# <div class="head">
# <span class="logo"><a href="/">
# <img alt="东方天气网" class="logoImg opacityImg opacityImg" src="//tianqi.eastday.com/jscss/v25/images/new-logo.png">
# <h2>东方天气</h2>
# </img></a></span>
# <span class="tsearch" id="location_search_box"></span>
# <div class="myfollow yWeatherIcon" id="my_follow_box"></div><!--我的收藏-->
# </div>
# <!--台风专题入口 <div class="corner-rt"><a href="http://tianqi.eastday.com/news/2016_03_hanchao.htm" onclick="allCount('tianqi_hanchao2')" target="_blank"><img alt="寒潮来袭" height="100" src="//tianqi.eastday.com/jscss/v25//theme2/img/hanchao.png" width="100"></a></div><style> .corner-rt{ position:absolute; right:0; top:0; } </style><script> $(window).bind("resize", function() { var cornerRt; cornerRt = $(".corner-rt"); if ($(this).width() <= 1200) { cornerRt.hide(); } else { cornerRt.show(); } }).trigger("resize"); </script>-->
# </div><!-- /head_w -->
# <div class="navArea">
# <div class="nav_mod">
# <ul>
# <li class="first_item"><a href="/" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=1"> 首页 </a><i></i></li>
# <li>
# <a href="/city/" id="nav_city_tianqi" onclick="return _link_click(event);" rel="nofollow" suffix="btype=index&amp;subtype=nav&amp;idx=2"> 城市天气 </a><i></i>
# </li>
# <li>
# <a href="/air.html" id="nav_city_air" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=3">空气质量</a><i></i>
# </li>
# <li><a class="current" href="/history.html" id="nav_city_history" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=5">
#                         历史天气 </a><i></i></li>
# <li><a href="/jingdian/" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=4">
#                         景点天气 </a><i></i></li>
# <li><a href="/china.html" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=7"> 国内天气 </a><i></i></li>
# <li><a href="/asia.html" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=6"> 国际天气 </a><i></i></li>
# <li><a href="/news/" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=7"> 天气新闻 </a><i></i></li>
# <li><a href="/24xiaoshi/video.html" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=8">天气视频 </a><i></i></li>
# <li style="display:none;"><a href="/plugin/" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=nav&amp;idx=9" target="_blank">天气插件</a><i></i></li>
# </ul>
# <div class="lnktools"></div>
# <!-- <span class="n_r"></span> -->
# </div>
# </div>
# <div class="wrap" id="wrap"><!-- nav_mod -->
# <!-- /nav_mod -->
# <div class="main_content">
# <link href="//tianqi.eastday.com/jscss/v25/css/history.css" rel="stylesheet" type="text/css">
# <div class="path">
# <div style="float:right;">
# <script>
#                         (function() {
#                             var __qid = getQueryString('qid');
#                             var is_bottom = '0';
#                             var page_title = '';
#                             if ($.inArray(__qid,__noAd)==-1||is_bottom==0||page_title!='h5_city'){
#                                 var corp_id = '2474370';
#                                 var ad_size = '1000,34';
#                                 var display = 'inlay-fix';
#                                 if ( __qid && typeof(__da) != 'undefined' && __da[__qid] && __da[__qid][corp_id] ) {
#                                     corp_id = __da[__qid][corp_id];
#                                 }
#                                 var s = "_" + Math.random().toString(36).slice(2);
#                                 document.write('<div id="' + s + '"></div>');
#                                 (window.slotbydup=window.slotbydup || []).push({
#                                     id: corp_id,
#                                     container: s,
#                                     size: ad_size,
#                                     display: display
#                                 });
#                             }
#                         })();
#                         </script>
# </div>
# <div style="float: right;padding-right:10px; "> 猜你喜欢 :</div>
# <div class="path_lf"> 当前位置：
#         <a href="/" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=position&amp;idx=1" title="东方天气网">东方天气网</a>
# <span>&gt;</span><a href="/zhejiang/" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=position&amp;idx=2" title="浙江历史天气">浙江历史天气</a>
# <span>&gt;</span><a href="/hangzhou_history/58457.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=position&amp;idx=3" title="杭州历史天气">杭州历史天气</a>
# </div>
# </div>
# <div class="ptb10">
# <div class="tShow-tit f20 cBlue">
# <span class="fr tShow-more"><span class="cGray">相关地区历史天气：</span>
# <a class="cBlue tuder" href="/yuhang_history/71230.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=1" title="余杭历史天气">
#       余杭      </a>
# <a class="cBlue tuder" href="/shangcheng/a120813.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=2" title="上城历史天气">
#       上城      </a>
# <a class="cBlue tuder" href="/jianggan/a680.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=3" title="江干历史天气">
#       江干      </a>
# <a class="cBlue tuder" href="/xiacheng/a41279.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=4" title="下城历史天气">
#       下城      </a>
# <a class="cBlue tuder" href="/chunan_history/70914.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=5" title="淳安历史天气">
#       淳安      </a>
# <a class="cBlue tuder" href="/fuyang_history/60658.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=6" title="富阳历史天气">
#       富阳      </a>
# <span class="tShowMore tShow-more-add dbIb"></span> </span>
# <h1 class="fl f20">杭州历史天气</h1>
# <div class="select-city">
# <a class="switch" data-allcount="tq_cityswitch1" href="#" id="btnSwitchCity">
# <span>切换城市</span>
# <i></i>
# <div class="mask"></div>
# </a>
# <div class="switch-layer pop-layer" id="switchCityLayer" style="display: none;">
# <input id="lc_id" name="lc_id" type="hidden">
# <select id="switchProvSelect">
# </select>
# <select id="switchCitySelect">
# </select>
# <select id="switchCountySelect">
# </select>
# <div class="btn-pools"><a class="btn-confirm" href="#" id="submitChangeCity" onclick="return _link_click(event);" suffix="btype=index&amp;subtype=switchCity&amp;idx=1">确定</a><a class="btn-cancel" href="#" id="cancelChangeCity">取消</a>
# </div>
# </input></div>
# </div>
# <script>
# $(function(){
#     $("#btnSwitchCity").click(function (e) {
#     isShowing = $(this).parent().hasClass('select-city-hover');
#     mytoggleLayer(isShowing, $("#switchCityLayer"), $(this).parent());
#     cancelEvent(e);
#     allCount($(this).attr('data-allCount'));
#     return false;
#     });
#     $('#submitChangeCity').click(function () {
#         var re_url = $("#switchCountySelect").find("option:selected").attr("re_url");
#         var qidurl=getQueryString('qid') ? '?qid=' + getQueryString('qid'):"";
#         window.location.href = re_url+qidurl;
#         return false;
#     });
#     $('#cancelChangeCity').click(function (e) {
#         mytoggleLayer(true, $("#switchCityLayer"), $(this).parent());
#         cancelEvent(e);
#         return false;
#     });
#     if ($('#switchProvSelect').length > 0) {
#         seedProvCityCountySelect('switchProvSelect', 'switchCitySelect', 'switchCountySelect', '_history');
#         $('#switchProvSelect,#switchCitySelect,#switchCountySelect').click(function (e) {
#             cancelEvent(e);
#         });
#         $('#cityRemember').click(function (e) {
#             allCount('tq_local_switch_remember');
#             cancelEvent(e);
#             if ($('#switchCountySelect').val().indexOf('a') > -1) {
#                 $('#cityRemember').attr({"checked": false});
#                 return false;
#             }
#         });
#     }
# });
# </script> <div class="tShow-more-box hidden">
# <a class="cBlue" href="/tonglu_history/60195.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=7" title="桐庐历史天气">
#         桐庐        </a>
# <a class="cBlue" href="/gongshu/a4502.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=8" title="拱墅历史天气">
#         拱墅        </a>
# <a class="cBlue" href="/linan_history/60875.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=9" title="临安历史天气">
#         临安        </a>
# <a class="cBlue" href="/xiaoshan_history/60175.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=10" title="萧山历史天气">
#         萧山        </a>
# <a class="cBlue" href="/xihu/a8396.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=11" title="西湖历史天气">
#         西湖        </a>
# <a class="cBlue" href="/binjiang/a10262.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=12" title="滨江历史天气">
#         滨江        </a>
# <a class="cBlue" href="/jiande_history/60176.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=relativeArea&amp;idx=13" title="建德历史天气">
#         建德        </a>
# </div>
# </div>
# </div>
# <div class="history-page clearfix">
# <div class="col-1">
# <div class="module module-data">
# <div class="meta" id="hisContent">
# <div class="btitle clearfix"><h2>杭州<span id="zhuyue">2017年06月</span>天气概况 </h2>
# <!-- <div class="switch"><a id="switchHisCity" href="#" class="switch-name"><i></i>切换城市</a>
#                     <div id="switchLayer" class="switch-layer pop-layer" style="display: none;">
#                         <div class="filter"></div>
#                         <div class="choose"><select name="province_ls" id="selectProv" class="province_ls">
#                             </select><select name="chengs_ls" id="chengs_ls" class="chengs_ls">
#                             </select><select name="xian_ls" id="cityqx_ls" class="cityqx_ls">
#                             </select>
#                             <input type="hidden" value="12" name="hiddenpvid_ls" id="hiddenpvid_ls">
#                             <a id="buttonsdm_dz" href="javascript:void(0);" class="submit">确认</a>
#                             <input type="hidden" value="58457" id="hisCity">
#                             <input type="hidden" value="2017" id="hisYear">
#                             <input type="hidden" value="06" id="hisMonth">
#                             <input type="hidden" value="2017" id="currYear">
#                             <input type="hidden" value="06" id="currMonth">
#                         </div>
#                     </div>
#                 </div> -->
# <div class="posRt">
# <div class="date-select date-select-year" id="chooseHisYear">
# <div class="field">2017年</div>
# <i class="trigger"></i>
# <ul class="list pop-layer" style="display: none;">
# <li data-val="year-2011" redirect_uri="/hangzhou_history/58457_201106.html?btype=switchCity&amp;subtype=year&amp;idx=1">2011年</li>
# <li data-val="year-2012" redirect_uri="/hangzhou_history/58457_201206.html?btype=switchCity&amp;subtype=year&amp;idx=2">2012年</li>
# <li data-val="year-2013" redirect_uri="/hangzhou_history/58457_201306.html?btype=switchCity&amp;subtype=year&amp;idx=3">2013年</li>
# <li data-val="year-2014" redirect_uri="/hangzhou_history/58457_201406.html?btype=switchCity&amp;subtype=year&amp;idx=4">2014年</li>
# <li data-val="year-2015" redirect_uri="/hangzhou_history/58457_201506.html?btype=switchCity&amp;subtype=year&amp;idx=5">2015年</li>
# <li data-val="year-2016" redirect_uri="/hangzhou_history/58457_201606.html?btype=switchCity&amp;subtype=year&amp;idx=6">2016年</li>
# <li data-val="year-2017" redirect_uri="/hangzhou_history/58457_201701.html?btype=switchCity&amp;subtype=year&amp;idx=7">2017年</li>
# </ul>
# </div>
# <div class="date-select date-select-month" id="chooseHisMonth">
# <div class="field">06月</div>
# <i class="trigger"></i>
# <ul class="list pop-layer" style="display: none;">
# <li data-val="month-1" redirect_uri="/hangzhou_history/58457_201701.html?btype=switchCity&amp;subtype=month&amp;idx=1">1月</li>
# <li data-val="month-2" redirect_uri="/hangzhou_history/58457_201702.html?btype=switchCity&amp;subtype=month&amp;idx=2">2月</li>
# <li data-val="month-3" redirect_uri="/hangzhou_history/58457_201703.html?btype=switchCity&amp;subtype=month&amp;idx=3">3月</li>
# <li data-val="month-4" redirect_uri="/hangzhou_history/58457_201704.html?btype=switchCity&amp;subtype=month&amp;idx=4">4月</li>
# <li data-val="month-5" redirect_uri="/hangzhou_history/58457_201705.html?btype=switchCity&amp;subtype=month&amp;idx=5">5月</li>
# <li data-val="month-6" redirect_uri="/hangzhou_history/58457_201706.html?btype=switchCity&amp;subtype=month&amp;idx=6">6月</li>
# </ul>
# </div>
# </div>
# </div>
# <div class="summa">
# <ul class="has_aqi" id="weather_ul2">
# <li>
# <div><strong>平均高温：</strong><span class="cOrange">28℃</span>
# <strong>平均低温：</strong><span class="cBlue">21℃</span>
# </div>
# <div><strong>平均空气质量指数：49 </strong></div>
# </li>
# <li>
# <div><strong>极端高温：</strong><span class="cOrange">32℃</span><span class="date"> （2017-06-08）</span>
# </div>
# <div><strong>空气最好：23</strong><span class="aqi-lv1"> 空气优</span><span class="date">（06月24日）</span>
# </div>
# </li>
# <li>
# <div><strong>极端低温：</strong><span class="cBlue">18℃</span><span class="date"> （2017-06-16）</span>
# </div>
# <div><strong>空气最差：105</strong><span class="aqi-lv3"> 轻度污染</span><span class="date">（06月01日）</span>
# </div>
# </li>
# </ul>
# </div>
# <div style="width:686px;height:80px;">
# <script>
#                         (function() {
#                             var __qid = getQueryString('qid');
#                             var is_bottom = '0';
#                             var page_title = '';
#                             if ($.inArray(__qid,__noAd)==-1||is_bottom==0||page_title!='h5_city'){
#                                 var corp_id = '2599328';
#                                 var ad_size = '695,80';
#                                 var display = 'inlay-fix';
#                                 if ( __qid && typeof(__da) != 'undefined' && __da[__qid] && __da[__qid][corp_id] ) {
#                                     corp_id = __da[__qid][corp_id];
#                                 }
#                                 var s = "_" + Math.random().toString(36).slice(2);
#                                 document.write('<div id="' + s + '"></div>');
#                                 (window.slotbydup=window.slotbydup || []).push({
#                                     id: corp_id,
#                                     container: s,
#                                     size: ad_size,
#                                     display: display
#                                 });
#                             }
#                         })();
#                         </script>
# </div>
# <div class="btitle clearfix"><h2>杭州<span id="zhuyue">2017年06月</span>天气详情</h2>
# </div>
# <div class="data-table" id="weather_tab">
# <table>
# <colgroup>
# <col width="24%">
# <col width="12%">
# <col width="12%">
# <col width="15%">
# <col width="15%">
# <col width="10%">
# <col width="12%">
# </col></col></col></col></col></col></col></colgroup>
# <thead>
# <tr>
# <th>日期</th>
# <th class="center">最高气温</th>
# <th class="center">最低气温</th>
# <th>天气情况</th>
# <th>风向风力</th>
# <th colspan="2">空气质量情况</th>
# </tr>
# </thead>
# <tbody>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-01<span class="week">星期四</span></td>
# <td class="center"><span class="red">29℃</span></td>
# <td class="center"><span class="blue">23℃</span></td>
# <td>阵雨~多云</td>
# <td>东南风</td>
# <td><label class="number">105</label></td><td><span class="aqi-lv3">轻度污染</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-02<span class="week">星期五</span></td>
# <td class="center"><span class="red">29℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>多云</td>
# <td>东风</td>
# <td><label class="number">79</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-03<span class="week">星期六</span></td>
# <td class="center"><span class="red">31℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>多云~晴</td>
# <td>东风</td>
# <td><label class="number">70</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-04<span class="week">星期日</span></td>
# <td class="center"><span class="red">29℃</span></td>
# <td class="center"><span class="blue">20℃</span></td>
# <td>多云~阴</td>
# <td>东风</td>
# <td><label class="number">47</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-05<span class="week">星期一</span></td>
# <td class="center"><span class="red">23℃</span></td>
# <td class="center"><span class="blue">20℃</span></td>
# <td>中到大雨~阵雨</td>
# <td>东风</td>
# <td><label class="number">39</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-06<span class="week">星期二</span></td>
# <td class="center"><span class="red">27℃</span></td>
# <td class="center"><span class="blue">20℃</span></td>
# <td>阵雨~阴</td>
# <td>西风</td>
# <td><label class="number">41</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-07<span class="week">星期三</span></td>
# <td class="center"><span class="red">30℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>多云</td>
# <td>西北风</td>
# <td><label class="number">47</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-08<span class="week">星期四</span></td>
# <td class="center"><span class="red">32℃</span></td>
# <td class="center"><span class="blue">23℃</span></td>
# <td>多云~阴</td>
# <td>东南风</td>
# <td><label class="number">94</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-09<span class="week">星期五</span></td>
# <td class="center"><span class="red">30℃</span></td>
# <td class="center"><span class="blue">24℃</span></td>
# <td>阵雨</td>
# <td>南风</td>
# <td><label class="number">72</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-10<span class="week">星期六</span></td>
# <td class="center"><span class="red">30℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>雷阵雨~中雨</td>
# <td>西南风</td>
# <td><label class="number">34</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-11<span class="week">星期日</span></td>
# <td class="center"><span class="red">25℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>中到大雨</td>
# <td>东北风</td>
# <td><label class="number">32</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-12<span class="week">星期一</span></td>
# <td class="center"><span class="red">23℃</span></td>
# <td class="center"><span class="blue">19℃</span></td>
# <td>中到大雨</td>
# <td>东风</td>
# <td><label class="number">30</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-13<span class="week">星期二</span></td>
# <td class="center"><span class="red">22℃</span></td>
# <td class="center"><span class="blue">20℃</span></td>
# <td>中到大雨~阵雨</td>
# <td>东北风</td>
# <td><label class="number">31</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-14<span class="week">星期三</span></td>
# <td class="center"><span class="red">26℃</span></td>
# <td class="center"><span class="blue">19℃</span></td>
# <td>阵雨~阴</td>
# <td>东北风</td>
# <td><label class="number">39</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-15<span class="week">星期四</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">19℃</span></td>
# <td>阴</td>
# <td>东风</td>
# <td><label class="number">54</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-16<span class="week">星期五</span></td>
# <td class="center"><span class="red">27℃</span></td>
# <td class="center"><span class="blue">18℃</span></td>
# <td>阴~多云</td>
# <td>东南风</td>
# <td><label class="number">57</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-17<span class="week">星期六</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">19℃</span></td>
# <td>多云</td>
# <td>东风</td>
# <td><label class="number">46</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-18<span class="week">星期日</span></td>
# <td class="center"><span class="red">30℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>多云~阴</td>
# <td>东南风</td>
# <td><label class="number">42</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-19<span class="week">星期一</span></td>
# <td class="center"><span class="red">27℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨</td>
# <td>东南风</td>
# <td><label class="number">36</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-20<span class="week">星期二</span></td>
# <td class="center"><span class="red">26℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨~阴</td>
# <td>东风</td>
# <td><label class="number">48</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-21<span class="week">星期三</span></td>
# <td class="center"><span class="red">29℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨</td>
# <td>东南风</td>
# <td><label class="number">57</label></td><td><span class="aqi-lv2">良</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-22<span class="week">星期四</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨~阴</td>
# <td>东风</td>
# <td><label class="number">42</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-23<span class="week">星期五</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">25℃</span></td>
# <td>中雨</td>
# <td>东南风</td>
# <td><label class="number">50</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-24<span class="week">星期六</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">23℃</span></td>
# <td>暴雨~大雨</td>
# <td>西南风</td>
# <td><label class="number">23</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-25<span class="week">星期日</span></td>
# <td class="center"><span class="red">26℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>暴雨~阵雨</td>
# <td>西南风</td>
# <td><label class="number">27</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-26<span class="week">星期一</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">21℃</span></td>
# <td>阴</td>
# <td>西南风</td>
# <td><label class="number">47</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-27<span class="week">星期二</span></td>
# <td class="center"><span class="red">28℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨</td>
# <td>南风</td>
# <td><label class="number">50</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# <tr onmouseout="this.style.backgroundColor=''" onmouseover="this.style.backgroundColor='#f1f1f1'" style="">
# <td>2017-06-28<span class="week">星期三</span></td>
# <td class="center"><span class="red">27℃</span></td>
# <td class="center"><span class="blue">22℃</span></td>
# <td>阵雨~中雨</td>
# <td>南风</td>
# <td><label class="number">45</label></td><td><span class="aqi-lv1">优</span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="page" id="prevNextBtn">
# <a class="prev " href="/hangzhou_history/58457_201705.html?btype=historyWeather&amp;subtype=pre&amp;idx=1">上一月</a>
# <a class="next next-disabled" href="javascript:void(0)">下一月</a>
# </div>
# <div class="btitle clearfix"><h2>杭州周边城市6月天气</h2></div>
# <div class="todayW-zb pt20 mb20 ov">
# <div class="todayW-zb-cont">
# <a href="/shanghai_history/58362_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=1" target="_blank" title="上海6月天气天气">
#                     上海6月天气</a>
# <a href="/shaoxing_history/58453_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=2" target="_blank" title="绍兴6月天气天气">
#                     绍兴6月天气</a>
# <a href="/huangshan_history/70931_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=3" target="_blank" title="黄山6月天气天气">
#                     黄山6月天气</a>
# <a href="/xuancheng_history/58433_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=4" target="_blank" title="宣城6月天气天气">
#                     宣城6月天气</a>
# <a href="/huzhou_history/58450_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=5" target="_blank" title="湖州6月天气天气">
#                     湖州6月天气</a>
# <a href="/ningbo_history/58465_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=6" target="_blank" title="宁波6月天气天气">
#                     宁波6月天气</a>
# <a href="/jiaxing_history/58452_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=7" target="_blank" title="嘉兴6月天气天气">
#                     嘉兴6月天气</a>
# <a href="/quzhou_history/58633_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=8" target="_blank" title="衢州6月天气天气">
#                     衢州6月天气</a>
# <a href="/zhoushan_history/58477_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=9" target="_blank" title="舟山6月天气天气">
#                     舟山6月天气</a>
# <a href="/suzhou_history/58357_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=10" target="_blank" title="苏州6月天气天气">
#                     苏州6月天气</a>
# <a href="/wuxi_history/58354_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=11" target="_blank" title="无锡6月天气天气">
#                     无锡6月天气</a>
# <a href="/jinhua_history/58549_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=12" target="_blank" title="金华6月天气天气">
#                     金华6月天气</a>
# <a href="/qingpu_history/60007_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=13" target="_blank" title="青浦6月天气天气">
#                     青浦6月天气</a>
# <a href="/chongming_history/60005_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=14" target="_blank" title="崇明6月天气天气">
#                     崇明6月天气</a>
# <a href="/hongkou_history/a53054_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=15" target="_blank" title="虹口6月天气天气">
#                     虹口6月天气</a>
# <a href="/pudong_history/71146_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=16" target="_blank" title="浦东6月天气天气">
#                     浦东6月天气</a>
# <a href="/changning_history/a10742_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=17" target="_blank" title="长宁6月天气天气">
#                     长宁6月天气</a>
# <a href="/xuhui_history/71147_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=18" target="_blank" title="徐汇6月天气天气">
#                     徐汇6月天气</a>
# <a href="/yangpu_history/a100531_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=19" target="_blank" title="杨浦6月天气天气">
#                     杨浦6月天气</a>
# <a href="/baoshan_history/71072_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=surCities&amp;idx=20" target="_blank" title="宝山6月天气天气">
#                     宝山6月天气</a>
# </div>
# </div>
# <div style="text-align: center;">
# <script>
#                         (function() {
#                             var __qid = getQueryString('qid');
#                             var is_bottom = '0';
#                             var page_title = '';
#                             if ($.inArray(__qid,__noAd)==-1||is_bottom==0||page_title!='h5_city'){
#                                 var corp_id = '2599339';
#                                 var ad_size = '1000,34';
#                                 var display = 'inlay-fix';
#                                 if ( __qid && typeof(__da) != 'undefined' && __da[__qid] && __da[__qid][corp_id] ) {
#                                     corp_id = __da[__qid][corp_id];
#                                 }
#                                 var s = "_" + Math.random().toString(36).slice(2);
#                                 document.write('<div id="' + s + '"></div>');
#                                 (window.slotbydup=window.slotbydup || []).push({
#                                     id: corp_id,
#                                     container: s,
#                                     size: ad_size,
#                                     display: display
#                                 });
#                             }
#                         })();
#                         </script>
# </div> </div>
# <div class="angle angle-lt"></div>
# <div class="angle angle-rt"></div>
# <div class="angle angle-lb"></div>
# <div class="angle angle-rb"></div>
# </div>
# </div>
# <div class="col-2 module">
# <div class="btitle hotcity"><h2>2017年杭州历史天气</h2></div>
# <div class="meta hotcity-cnt">
# <ul class="row3 clearfix auto">
# <li>
# <a href="/hangzhou_history/58457_201706.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=1" target="_blank" title="2017年6月天气">2017年6月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201705.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=2" target="_blank" title="2017年5月天气">2017年5月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201704.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=3" target="_blank" title="2017年4月天气">2017年4月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201703.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=4" target="_blank" title="2017年3月天气">2017年3月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201702.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=5" target="_blank" title="2017年2月天气">2017年2月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201701.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2017&amp;idx=6" target="_blank" title="2017年1月天气">2017年1月天气</a>
# </li>
# </ul>
# </div>
# <div class="btitle hotcity"><h2>2016年杭州历史天气</h2></div>
# <div class="meta hotcity-cnt">
# <ul class="row3 clearfix auto">
# <li>
# <a href="/hangzhou_history/58457_201612.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=1" target="_blank" title="2016年12月天气">2016年12月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201611.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=2" target="_blank" title="2016年11月天气">2016年11月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201610.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=3" target="_blank" title="2016年10月天气">2016年10月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201609.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=4" target="_blank" title="2016年9月天气">2016年9月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201608.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=5" target="_blank" title="2016年8月天气">2016年8月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201607.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=6" target="_blank" title="2016年7月天气">2016年7月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201606.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=7" target="_blank" title="2016年6月天气">2016年6月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201605.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=8" target="_blank" title="2016年5月天气">2016年5月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201604.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=9" target="_blank" title="2016年4月天气">2016年4月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201603.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=10" target="_blank" title="2016年3月天气">2016年3月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201602.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=11" target="_blank" title="2016年2月天气">2016年2月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201601.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2016&amp;idx=12" target="_blank" title="2016年1月天气">2016年1月天气</a>
# </li>
# </ul>
# </div>
# <div class="btitle hotcity"><h2>2015年杭州历史天气</h2></div>
# <div class="meta hotcity-cnt">
# <ul class="row3 clearfix auto">
# <li>
# <a href="/hangzhou_history/58457_201512.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=1" target="_blank" title="2015年12月天气">2015年12月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201511.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=2" target="_blank" title="2015年11月天气">2015年11月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201510.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=3" target="_blank" title="2015年10月天气">2015年10月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201509.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=4" target="_blank" title="2015年9月天气">2015年9月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201508.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=5" target="_blank" title="2015年8月天气">2015年8月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201507.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=6" target="_blank" title="2015年7月天气">2015年7月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201506.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=7" target="_blank" title="2015年6月天气">2015年6月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201505.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=8" target="_blank" title="2015年5月天气">2015年5月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201504.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=9" target="_blank" title="2015年4月天气">2015年4月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201503.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=10" target="_blank" title="2015年3月天气">2015年3月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201502.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=11" target="_blank" title="2015年2月天气">2015年2月天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201501.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=2015&amp;idx=12" target="_blank" title="2015年1月天气">2015年1月天气</a>
# </li>
# </ul>
# </div>
# <div class="meta hotcity-cnt pt15">
# <ul class="row3 clearfix auto">
# <li>
# <a href="/hangzhou_history/58457_201401.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=otherYear&amp;idx=1" target="_blank" title="2014年杭州天气">2014年杭州天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201301.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=otherYear&amp;idx=2" target="_blank" title="2013年杭州天气">2013年杭州天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201201.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=otherYear&amp;idx=3" target="_blank" title="2012年杭州天气">2012年杭州天气</a>
# </li>
# <li>
# <a href="/hangzhou_history/58457_201101.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=otherYear&amp;idx=4" target="_blank" title="2011年杭州天气">2011年杭州天气</a>
# </li>
# </ul>
# </div>
# <div class="module module-money" style="margin-top:0px;">
# <div class="btitle"><h2>热门推荐</h2></div>
# <div style="padding-left:15px; padding-bottom:8px;">
# <script>
#                         (function() {
#                             var __qid = getQueryString('qid');
#                             var is_bottom = '0';
#                             var page_title = '';
#                             if ($.inArray(__qid,__noAd)==-1||is_bottom==0||page_title!='h5_city'){
#                                 var corp_id = '2474436';
#                                 var ad_size = '1000,34';
#                                 var display = 'inlay-fix';
#                                 if ( __qid && typeof(__da) != 'undefined' && __da[__qid] && __da[__qid][corp_id] ) {
#                                     corp_id = __da[__qid][corp_id];
#                                 }
#                                 var s = "_" + Math.random().toString(36).slice(2);
#                                 document.write('<div id="' + s + '"></div>');
#                                 (window.slotbydup=window.slotbydup || []).push({
#                                     id: corp_id,
#                                     container: s,
#                                     size: ad_size,
#                                     display: display
#                                 });
#                             }
#                         })();
#                         </script>
# </div> </div>
# <div class="btitle hotcity"><h2>杭州天气新闻</h2></div>
# <div class="meta hotcity-cnt">
# <ul class="pl20 row4 clearfix auto">
# <li><a href="/news/9078.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=1" target="_blank" title="2016年07月25日杭州天气">2016年07月25日杭州天气</a></li>
# <li><a href="/news/8685.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=2" target="_blank" title="2016年07月24日杭州天气">2016年07月24日杭州天气</a></li>
# <li><a href="/news/8302.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=3" target="_blank" title="2016年07月23日杭州天气">2016年07月23日杭州天气</a></li>
# <li><a href="/news/7824.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=4" target="_blank" title="2016年07月22日杭州天气">2016年07月22日杭州天气</a></li>
# <li><a href="/news/7329.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=5" target="_blank" title="2016年07月21日杭州天气">2016年07月21日杭州天气</a></li>
# <li><a href="/news/6863.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=6" target="_blank" title="2016年07月20日杭州天气">2016年07月20日杭州天气</a></li>
# <li><a href="/news/6387.html" onclick="return _link_click(event);" suffix="btype=historyWeather&amp;subtype=weatherNews&amp;idx=7" target="_blank" title="2016年07月19日杭州天气">2016年07月19日杭州天气</a></li>
# </ul>
# </div>
# <!-- <div class="btitle hotcity"><h2>热门城市历史天气</h2></div>
#         <div class="meta hotcity-cnt">
#             <ul class="row3 clearfix auto">
#
#                                         <li>
#                         <a href="/huhehaote_history/53463.html" target="_blank" title="呼和浩特">呼和浩特天气</a>
#                     </li>
#                                         <li>
#                         <a href="/xian_history/57036.html" target="_blank" title="西安">西安天气</a>
#                     </li>
#                                         <li>
#                         <a href="/fuzhou_history/58847.html" target="_blank" title="福州">福州天气</a>
#                     </li>
#                                         <li>
#                         <a href="/taiyuan_history/53772.html" target="_blank" title="太原">太原天气</a>
#                     </li>
#                                         <li>
#                         <a href="/guiyang_history/57816.html" target="_blank" title="贵阳">贵阳天气</a>
#                     </li>
#                                         <li>
#                         <a href="/jinan_history/54823.html" target="_blank" title="济南">济南天气</a>
#                     </li>
#                                         <li>
#                         <a href="/changchun_history/54161.html" target="_blank" title="长春">长春天气</a>
#                     </li>
#                                         <li>
#                         <a href="/kunming_history/56778.html" target="_blank" title="昆明">昆明天气</a>
#                     </li>
#                                         <li>
#                         <a href="/guangzhou_history/59287.html" target="_blank" title="广州">广州天气</a>
#                     </li>
#                                         <li>
#                         <a href="/zhengzhou_history/57083.html" target="_blank" title="郑州">郑州天气</a>
#                     </li>
#                                         <li>
#                         <a href="/tianjin_history/54527.html" target="_blank" title="天津">天津天气</a>
#                     </li>
#                                         <li>
#                         <a href="/chengdu_history/56294.html" target="_blank" title="成都">成都天气</a>
#                     </li>
#                                         <li>
#                         <a href="/hefei_history/58321.html" target="_blank" title="合肥">合肥天气</a>
#                     </li>
#                                         <li>
#                         <a href="/nanning_history/59431.html" target="_blank" title="南宁">南宁天气</a>
#                     </li>
#                                         <li>
#                         <a href="/shijiazhuang_history/53698.html" target="_blank" title="石家庄">石家庄天气</a>
#                     </li>
#                                         <li>
#                         <a href="/changsha_history/57687.html" target="_blank" title="长沙">长沙天气</a>
#                     </li>
#                                         <li>
#                         <a href="/yinchuan_history/53614.html" target="_blank" title="银川">银川天气</a>
#                     </li>
#                                         <li>
#                         <a href="/wulumuqi_history/51463.html" target="_blank" title="乌鲁木齐">乌鲁木齐天气</a>
#                     </li>
#                                         <li>
#                         <a href="/xining_history/52866.html" target="_blank" title="西宁">西宁天气</a>
#                     </li>
#                                         <li>
#                         <a href="/haerbin_history/50953.html" target="_blank" title="哈尔滨">哈尔滨天气</a>
#                     </li>
#                                         <li>
#                         <a href="/hangzhou_history/58457.html" target="_blank" title="杭州">杭州天气</a>
#                     </li>
#                                         <li>
#                         <a href="/wuhan_history/57494.html" target="_blank" title="武汉">武汉天气</a>
#                     </li>
#                                         <li>
#                         <a href="/shanghai_history/58362.html" target="_blank" title="上海">上海天气</a>
#                     </li>
#                                         <li>
#                         <a href="/zhongqing_history/57516.html" target="_blank" title="重庆">重庆天气</a>
#                     </li>
#                                         <li>
#                         <a href="/lasa_history/55591.html" target="_blank" title="拉萨">拉萨天气</a>
#                     </li>
#                                         <li>
#                         <a href="/lanzhou_history/52889.html" target="_blank" title="兰州">兰州天气</a>
#                     </li>
#                                         <li>
#                         <a href="/nanjing_history/58238.html" target="_blank" title="南京">南京天气</a>
#                     </li>
#                                         <li>
#                         <a href="/nanchang_history/58606.html" target="_blank" title="南昌">南昌天气</a>
#                     </li>
#                                         <li>
#                         <a href="/shenyang_history/54342.html" target="_blank" title="沈阳">沈阳天气</a>
#                     </li>
#                                         <li>
#                         <a href="/haikou_history/59758.html" target="_blank" title="海口">海口天气</a>
#                     </li>
#                                         <li>
#                         <a href="/gaoxiong_history/59554.html" target="_blank" title="高雄">高雄天气</a>
#                     </li>
#                                         <li>
#                         <a href="/beijing_history/54511.html" target="_blank" title="北京">北京天气</a>
#                     </li>
#                                         <li>
#                         <a href="/aomen_history/45011.html" target="_blank" title="澳门">澳门天气</a>
#                     </li>
#                                         <li>
#                         <a href="/xianggang_history/45007.html" target="_blank" title="香港">香港天气</a>
#                     </li>
#                                         <li>
#                         <a href="/taipei_history/71294.html" target="_blank" title="台北">台北天气</a>
#                     </li>
#                                 </ul>
#
#         </div> -->
# </div>
# </div>
# <script>
#     $('#chooseHisYear .field, #chooseHisMonth .field').click(function () {
#         $('#chooseHisMonth li').removeClass('disabled');
#         var isShow = $(this).parent().find('ul', 0).css('display') == 'block';
#         mytoggleLayer(isShow, $(this).parent().find('ul', 0), $(this));
#         if ($('#currYear').val() == $('#hisYear').val()) {
#             $('#chooseHisMonth li').each(function (index, element) {
#                 if (index > $('#currMonth').val() - 1) {
#                     $(element).addClass('disabled');
#                 }else{
#                     $(element).removeClass('disabled');
#                 }
#             });
#         }
#         return false;
#     });
#     $('#chooseHisYear li, #chooseHisMonth li').click(function () {
#         var data = $(this).data('val').split('-');
#         var redirect_uri = $(this).attr('redirect_uri')+'&qid=' + getQueryString('qid');
#         window.location.href = redirect_uri;
#         $(this).parent().hide();
#     });
#
#
#     seedProvCityCountySelect('selectProv', 'chengs_ls', 'cityqx_ls',"_history");
#     $('#switchHisCity').click(function () {
#         var isShowing = $('#switchLayer').css('display') == 'block';
#         mytoggleLayer(isShowing, $('#switchLayer'), $(this));
#         return false;
#     });
#     $('#buttonsdm_dz').click(function () {
#         var re_url=$("#cityqx_ls").find("option:selected").attr("re_url");
#         window.location.href = re_url;
#     });
#
#
#
# </script>
# </link></div> <div class="footer">
# <div class="wp">
# <p class="p1">
# <!--                <a href="#" target="_blank">关于我们</a><span class="pipe">|</span>
#                 <a href="#" target="_blank">联系我们</a><span class="pipe">|</span>-->
# <!-- <a href="#" target="_blank">意见反馈</a><span class="pipe">|</span> -->
# <a href="/plugin/" target="_blank">天气插件</a><span class="pipe">|</span>
# <!-- <a href="#" target="_blank">网站专题</a><span class="pipe">|</span>
#                 <a href="/news/" target="_blank">最近更新 </a><span class="pipe">|</span> -->
# <a href="/seo/sitemap-city.html" target="_blank">网站地图</a>
# <span class="pipe">|</span>
# <a href="/seo/sitemapindex.xml" target="_blank">XML地图</a>
# <!--<span class="pipe">|</span>-->
# <span class="pipe">|</span>
# <a href="/aboutus.html" target="_blank">关于我们</a>
# </p>
# <p class="p2">
#                 Copyright © 2016 <a href="//tianqi.eastday.com/" target="_blank"> 东方天气网</a>  All Rights Reserved. <a href="//news.eastday.com/images/ditu/zzzs.htm" rel="nofollow" target="_blank">ICP证沪B2-20050088号</a>  上东方天气，知天下气候。
#             </p>
# <p class="p2">
#                                 东方天气网是东方网旗下的天气预报网，为您提供全球城市的7-15天天气查询，PM2.5查询等，以及全国景点天气预报，空气质量监控。
#                             </p>
# </div>
# </div>
# </div><!-- end of container-->
# <!--[if IE 6]>
# <div id="poplayerbg" class="poplayerbg">
#     <iframe frameborder="0" src="about:blank;"
#             style="position:absolute;top:0px;right:0px;width:100%;height:100%;z-index:-1;filter:alpha(opacity=0);"></iframe>
# </div>
# </div>
# <![endif]-->
# <script>
#     loadTopBanner();
#     $('#poplayer').appendTo('body');
# </script>
# <div style="display: none">
# <script>
#         var _hmt = _hmt || [];
#         (function() {
#             var hm = document.createElement("script");
#             hm.src = "//hm.baidu.com/hm.js?ef6cc68855e4c4aae7df90c55a6786af";
#             var s = document.getElementsByTagName("script")[0];
#             s.parentNode.insertBefore(hm, s);
#         })();
#     </script>
# <script>
#     //保存日记到cookie
#     $('body').on('click','a',function(){
#         $this=$(this);
#         if($this.attr('suffix') && ($this.attr('suffix').indexOf("gg") == -1)){
#             $.cookie("logdata",$(this).attr('suffix'),{path:'/'});
#         }
#     });
#     </script>
# </div>
# </div></body>
# </html>

# %%
for weather in soup.select('tbody'):
    for i in range(len(weather.select('tr'))):
        #print weather.select('tr')[i].text
        print weather.select('tr')[i].select('td')[0].text 
        #print weather.select('tr')[i].select('td')[0].select('.week')[0].text 
        print weather.select('tr')[i].select('td')[1].text
        print weather.select('tr')[i].select('td')[2].text
        print weather.select('tr')[i].select('td')[3].text
        print weather.select('tr')[i].select('td')[4].text
        print weather.select('tr')[i].select('td')[5].text
        print weather.select('tr')[i].select('td')[6].text
# Out:
# 2017-06-01星期四
# 29℃
# 23℃
# 阵雨~多云
# 东南风
# 105
# 轻度污染
# 2017-06-02星期五
# 29℃
# 21℃
# 多云
# 东风
# 79
# 良
# 2017-06-03星期六
# 31℃
# 22℃
# 多云~晴
# 东风
# 70
# 良
# 2017-06-04星期日
# 29℃
# 20℃
# 多云~阴
# 东风
# 47
# 优
# 2017-06-05星期一
# 23℃
# 20℃
# 中到大雨~阵雨
# 东风
# 39
# 优
# 2017-06-06星期二
# 27℃
# 20℃
# 阵雨~阴
# 西风
# 41
# 优
# 2017-06-07星期三
# 30℃
# 21℃
# 多云
# 西北风
# 47
# 优
# 2017-06-08星期四
# 32℃
# 23℃
# 多云~阴
# 东南风
# 94
# 良
# 2017-06-09星期五
# 30℃
# 24℃
# 阵雨
# 南风
# 72
# 良
# 2017-06-10星期六
# 30℃
# 22℃
# 雷阵雨~中雨
# 西南风
# 34
# 优
# 2017-06-11星期日
# 25℃
# 21℃
# 中到大雨
# 东北风
# 32
# 优
# 2017-06-12星期一
# 23℃
# 19℃
# 中到大雨
# 东风
# 30
# 优
# 2017-06-13星期二
# 22℃
# 20℃
# 中到大雨~阵雨
# 东北风
# 31
# 优
# 2017-06-14星期三
# 26℃
# 19℃
# 阵雨~阴
# 东北风
# 39
# 优
# 2017-06-15星期四
# 28℃
# 19℃
# 阴
# 东风
# 54
# 良
# 2017-06-16星期五
# 27℃
# 18℃
# 阴~多云
# 东南风
# 57
# 良
# 2017-06-17星期六
# 28℃
# 19℃
# 多云
# 东风
# 46
# 优
# 2017-06-18星期日
# 30℃
# 21℃
# 多云~阴
# 东南风
# 42
# 优
# 2017-06-19星期一
# 27℃
# 22℃
# 阵雨
# 东南风
# 36
# 优
# 2017-06-20星期二
# 26℃
# 22℃
# 阵雨~阴
# 东风
# 48
# 优
# 2017-06-21星期三
# 29℃
# 22℃
# 阵雨
# 东南风
# 57
# 良
# 2017-06-22星期四
# 28℃
# 22℃
# 阵雨~阴
# 东风
# 42
# 优
# 2017-06-23星期五
# 28℃
# 25℃
# 中雨
# 东南风
# 50
# 优
# 2017-06-24星期六
# 28℃
# 23℃
# 暴雨~大雨
# 西南风
# 23
# 优
# 2017-06-25星期日
# 26℃
# 21℃
# 暴雨~阵雨
# 西南风
# 27
# 优
# 2017-06-26星期一
# 28℃
# 21℃
# 阴
# 西南风
# 47
# 优
# 2017-06-27星期二
# 28℃
# 22℃
# 阵雨
# 南风
# 50
# 优
# 2017-06-28星期三
# 27℃
# 22℃
# 阵雨~中雨
# 南风
# 45
# 优

# %%
import csv
fout = open('E:/Jupter/web_crawl/weather.csv','wb')#用‘w’时csv出现空行，改用‘wb’            
csv_writer = csv.writer(fout)
CsvHead=['Date','High_temp','Low_temp','Weather','Wind','Number','Qai_lel']
csv_writer.writerow(CsvHead)

for weather in soup.select('tbody'):
    for i in range(len(weather.select('tr'))):
        Date = weather.select('tr')[i].select('td')[0].text 
        High_temp = weather.select('tr')[i].select('td')[1].text
        Low_temp = weather.select('tr')[i].select('td')[2].text
        Weather = weather.select('tr')[i].select('td')[3].text
        Wind = weather.select('tr')[i].select('td')[4].text
        Number = weather.select('tr')[i].select('td')[5].text
        Qai_lel = weather.select('tr')[i].select('td')[6].text
        csv_writer.writerow([ x.encode('utf-8') for x in [Date,High_temp,Low_temp,Weather,Wind,Number,Qai_lel]])        
fout.close()
